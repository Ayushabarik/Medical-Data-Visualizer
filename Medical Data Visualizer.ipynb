# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("medical_examination.csv")

# %%
df['overweight']=(df['weight']/(df['height']/100)**2).apply
(lambda x : 1 if x > 25 else 0)
# Out:
# <function __main__.<lambda>(x)>

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  \
# ...

# %%
#Normalizing the data: 0 for 1(always good) and 1 for >1(always bad)
df['cholesterol']=df['cholesterol'].apply 
(lambda x : 0 if x==1 else 1)
# Out:
# <function __main__.<lambda>(x)>

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  \
# 0          0  18393       2     168    62.0    110     80
# 1          1  20228       1     156    85.0    140     90
# 2          2  18857       1     165    64.0    130     70
# 3          3  17623       2     169    82.0    150    100
# 4          4  17474       1     156    56.0    100     60
# ...      ...    ...     ...     ...     ...    ...    ...
# 69995  99993  19240       2     168    76.0    120     80
# 69996  99995  22601       1     158   126.0    140     90
# 69997  99996  19066       2     183   105.0    180     90
# 69998  99998  22431       1     163    72.0    135     80
# 69999  99999  20540       1     170    72.0    120     80
#
#                                              cholesterol  gluc  smoke  alco  \
# 0      <bound method Series.apply of 0        1\n1   ...     1      0     0
# 1      <bound method Series.apply of 0        1\n1   ...     1      0     0
# ...

# %%
df['gluc']=df['gluc'].apply 
(lambda x : 0 if x==1 else 1)
# Out:
# <function __main__.<lambda>(x)>

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  \
# 0          0  18393       2     168    62.0    110     80
# 1          1  20228       1     156    85.0    140     90
# 2          2  18857       1     165    64.0    130     70
# 3          3  17623       2     169    82.0    150    100
# 4          4  17474       1     156    56.0    100     60
# ...      ...    ...     ...     ...     ...    ...    ...
# 69995  99993  19240       2     168    76.0    120     80
# 69996  99995  22601       1     158   126.0    140     90
# 69997  99996  19066       2     183   105.0    180     90
# 69998  99998  22431       1     163    72.0    135     80
# 69999  99999  20540       1     170    72.0    120     80
#
#                                              cholesterol  \
# 0      <bound method Series.apply of 0        1\n1   ...
# 1      <bound method Series.apply of 0        1\n1   ...
# 2      <bound method Series.apply of 0        1\n1   ...
# ...

# %%
#cat plots using seaborn and melt function:

df_cat = pd.melt(frame = df, value_vars=['cholesterol','gluc','smoke','alco','active','overweight'], id_vars=['cardio'])

# %%
graph = sns.catplot(x="variable", col="cardio", hue="value", data=df_cat, kind="count")
graph.set_axis_labels("variable", "total")

# %%
#Heat Map

#Data cleaning:
df_heat=df[
        (df['ap_lo'] <= df['ap_hi']) & 
        (df['height'] >= df['height'].quantile(0.025)) &
        (df['height'] <= df['height'].quantile(0.975)) &
        (df['weight'] >= df['weight'].quantile(0.025)) &
        (df['weight'] <= df['weight'].quantile(0.975)) 
    ]    

#correlation matrix:
corr = df_heat.corr()

#Mask the upper triangle:
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, annot=True, fmt='.1f', mask=mask, vmin=.16, vmax=.32, center=0, square=True, linewidths=.5, cbar_kws={'shrink':.45, 'format':'%.2f'})
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5684\674378442.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <AxesSubplot:>
